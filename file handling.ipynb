# %%
file=open("student attendence.txt","w")
file.write("student name:\n sneha\n jyoti\n agassi\n hemanth\n madhu\n")
ticking={"sneha":"present","jyoti":"present","agassi":"present","hemanth":"absent","madhu":"present"}
print(ticking)
print(ticking["sneha"])
print(ticking["jyoti"])
print(ticking["agassi"])
print(ticking["hemanth"])
print(ticking["madhu"])
file.close()
# Out:
# {'sneha': 'present', 'jyoti': 'present', 'agassi': 'present', 'hemanth': 'absent', 'madhu': 'present'}
# present
# present
# present
# absent
# present

# %%
file=open("expense.txt","w")
file.write("01.01.2026 \n 2500rs \n alcohol")
file.close()

# %%
file=open("expense.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# 01.01.2026
#  2500rs
#  alcohol

# %%
import numpy as np
a=np.array([2,4,8])
b=np.array([3,9,12])
print(a+b)
# Out:
# [ 5 13 20]

# %%
x=np.array([
    [2,4],
    [6,7],
    [8,9]])

# %%
np.dot([6,7],([8,9]))
# Out:
# np.int64(111)

# %%
import random
outcomes=["spam","not spam"]
print(random.choice(outcomes))
# Out:
# not spam

# %%
import numpy as np
scores=[67,78,98]
print(np.mean(scores))
# Out:
# 81.0

# %%
w=7
Ir=0.3
for i in range(7):
    w=w+Ir
    print(w)
# Out:
# 7.3
# 7.6
# 7.8999999999999995
# 8.2
# 8.5
# 8.8
# 9.100000000000001
